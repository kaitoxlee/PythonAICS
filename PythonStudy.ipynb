# %% [markdown]
# <h1>目录<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#操作系统(科普章节)" data-toc-modified-id="操作系统(科普章节)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>操作系统(科普章节)</a></span></li><li><span><a href="#Python的关键点常识" data-toc-modified-id="Python的关键点常识-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Python的关键点常识</a></span></li><li><span><a href="#Python优点和缺点" data-toc-modified-id="Python优点和缺点-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Python优点和缺点</a></span><ul class="toc-item"><li><span><a href="#优点" data-toc-modified-id="优点-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>优点</a></span></li><li><span><a href="#缺点" data-toc-modified-id="缺点-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>缺点</a></span></li></ul></li><li><span><a href="#应用场景" data-toc-modified-id="应用场景-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>应用场景</a></span></li><li><span><a href="#注释" data-toc-modified-id="注释-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>注释</a></span><ul class="toc-item"><li><span><a href="#单行注释" data-toc-modified-id="单行注释-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>单行注释</a></span></li><li><span><a href="#多行注释" data-toc-modified-id="多行注释-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>多行注释</a></span></li><li><span><a href="#中文支持" data-toc-modified-id="中文支持-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>中文支持</a></span></li></ul></li><li><span><a href="#变量及类型" data-toc-modified-id="变量及类型-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>变量及类型</a></span></li><li><span><a href="#标识符" data-toc-modified-id="标识符-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>标识符</a></span><ul class="toc-item"><li><span><a href="#什么是标识符？" data-toc-modified-id="什么是标识符？-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>什么是标识符？</a></span></li><li><span><a href="#标识符命名规则" data-toc-modified-id="标识符命名规则-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>标识符命名规则</a></span></li><li><span><a href="#标识符书写" data-toc-modified-id="标识符书写-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>标识符书写</a></span></li></ul></li><li><span><a href="#关键字" data-toc-modified-id="关键字-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>关键字</a></span></li><li><span><a href="#输入与输出" data-toc-modified-id="输入与输出-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>输入与输出</a></span><ul class="toc-item"><li><span><a href="#输出" data-toc-modified-id="输出-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>输出</a></span></li><li><span><a href="#格式符号" data-toc-modified-id="格式符号-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>格式符号</a></span></li><li><span><a href="#输入" data-toc-modified-id="输入-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>输入</a></span></li></ul></li><li><span><a href="#运算符" data-toc-modified-id="运算符-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>运算符</a></span><ul class="toc-item"><li><span><a href="#算术运算符" data-toc-modified-id="算术运算符-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>算术运算符</a></span></li><li><span><a href="#赋值运算符" data-toc-modified-id="赋值运算符-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>赋值运算符</a></span></li><li><span><a href="#复合赋值运算符" data-toc-modified-id="复合赋值运算符-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>复合赋值运算符</a></span></li></ul></li><li><span><a href="#数据类型转换" data-toc-modified-id="数据类型转换-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>数据类型转换</a></span></li><li><span><a href="#判断语句" data-toc-modified-id="判断语句-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>判断语句</a></span><ul class="toc-item"><li><span><a href="#if-else" data-toc-modified-id="if-else-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>if-else</a></span></li><li><span><a href="#elif" data-toc-modified-id="elif-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>elif</a></span></li><li><span><a href="#if嵌套" data-toc-modified-id="if嵌套-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>if嵌套</a></span></li><li><span><a href="#猜拳游戏" data-toc-modified-id="猜拳游戏-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>猜拳游戏</a></span></li></ul></li><li><span><a href="#比较运算符/关系运算符" data-toc-modified-id="比较运算符/关系运算符-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>比较运算符/关系运算符</a></span></li><li><span><a href="#逻辑运算符" data-toc-modified-id="逻辑运算符-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>逻辑运算符</a></span></li><li><span><a href="#循环语句" data-toc-modified-id="循环语句-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>循环语句</a></span><ul class="toc-item"><li><span><a href="#while循环" data-toc-modified-id="while循环-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>while循环</a></span></li><li><span><a href="#1-100求和" data-toc-modified-id="1-100求和-15.2"><span class="toc-item-num">15.2&nbsp;&nbsp;</span>1-100求和</a></span></li><li><span><a href="#1-100偶数求和" data-toc-modified-id="1-100偶数求和-15.3"><span class="toc-item-num">15.3&nbsp;&nbsp;</span>1-100偶数求和</a></span></li><li><span><a href="#break" data-toc-modified-id="break-15.4"><span class="toc-item-num">15.4&nbsp;&nbsp;</span>break</a></span></li><li><span><a href="#continue" data-toc-modified-id="continue-15.5"><span class="toc-item-num">15.5&nbsp;&nbsp;</span>continue</a></span></li><li><span><a href="#总结" data-toc-modified-id="总结-15.6"><span class="toc-item-num">15.6&nbsp;&nbsp;</span>总结</a></span></li><li><span><a href="#99乘法表" data-toc-modified-id="99乘法表-15.7"><span class="toc-item-num">15.7&nbsp;&nbsp;</span>99乘法表</a></span></li><li><span><a href="#for循环" data-toc-modified-id="for循环-15.8"><span class="toc-item-num">15.8&nbsp;&nbsp;</span>for循环</a></span></li></ul></li><li><span><a href="#数据类型" data-toc-modified-id="数据类型-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>数据类型</a></span><ul class="toc-item"><li><span><a href="#string" data-toc-modified-id="string-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>string</a></span><ul class="toc-item"><li><span><a href="#<1>find-&amp;-rfind" data-toc-modified-id="<1>find-&amp;-rfind-16.1.1"><span class="toc-item-num">16.1.1&nbsp;&nbsp;</span>&lt;1&gt;find &amp; rfind</a></span></li><li><span><a href="#<2>index-&amp;-rindex" data-toc-modified-id="<2>index-&amp;-rindex-16.1.2"><span class="toc-item-num">16.1.2&nbsp;&nbsp;</span>&lt;2&gt;index &amp; rindex</a></span></li><li><span><a href="#<3>count" data-toc-modified-id="<3>count-16.1.3"><span class="toc-item-num">16.1.3&nbsp;&nbsp;</span>&lt;3&gt;count</a></span></li><li><span><a href="#<4>replace" data-toc-modified-id="<4>replace-16.1.4"><span class="toc-item-num">16.1.4&nbsp;&nbsp;</span>&lt;4&gt;replace</a></span></li><li><span><a href="#<5>split" data-toc-modified-id="<5>split-16.1.5"><span class="toc-item-num">16.1.5&nbsp;&nbsp;</span>&lt;5&gt;split</a></span></li><li><span><a href="#<6>capitalize" data-toc-modified-id="<6>capitalize-16.1.6"><span class="toc-item-num">16.1.6&nbsp;&nbsp;</span>&lt;6&gt;capitalize</a></span></li><li><span><a href="#<7>startswith" data-toc-modified-id="<7>startswith-16.1.7"><span class="toc-item-num">16.1.7&nbsp;&nbsp;</span>&lt;7&gt;startswith</a></span></li><li><span><a href="#<8>endswith" data-toc-modified-id="<8>endswith-16.1.8"><span class="toc-item-num">16.1.8&nbsp;&nbsp;</span>&lt;8&gt;endswith</a></span></li><li><span><a href="#<9>lower" data-toc-modified-id="<9>lower-16.1.9"><span class="toc-item-num">16.1.9&nbsp;&nbsp;</span>&lt;9&gt;lower</a></span></li><li><span><a href="#<10>upper" data-toc-modified-id="<10>upper-16.1.10"><span class="toc-item-num">16.1.10&nbsp;&nbsp;</span>&lt;10&gt;upper</a></span></li><li><span><a href="#<11>ljust-&amp;-rjust" data-toc-modified-id="<11>ljust-&amp;-rjust-16.1.11"><span class="toc-item-num">16.1.11&nbsp;&nbsp;</span>&lt;11&gt;ljust &amp; rjust</a></span></li><li><span><a href="#<12>center" data-toc-modified-id="<12>center-16.1.12"><span class="toc-item-num">16.1.12&nbsp;&nbsp;</span>&lt;12&gt;center</a></span></li><li><span><a href="#<13>lstrip-&amp;-rstrip-&amp;-strip" data-toc-modified-id="<13>lstrip-&amp;-rstrip-&amp;-strip-16.1.13"><span class="toc-item-num">16.1.13&nbsp;&nbsp;</span>&lt;13&gt;lstrip &amp; rstrip &amp; strip</a></span></li><li><span><a href="#<14>partition-&amp;-rpartition" data-toc-modified-id="<14>partition-&amp;-rpartition-16.1.14"><span class="toc-item-num">16.1.14&nbsp;&nbsp;</span>&lt;14&gt;partition &amp; rpartition</a></span></li><li><span><a href="#<15>splitlines---行分割" data-toc-modified-id="<15>splitlines---行分割-16.1.15"><span class="toc-item-num">16.1.15&nbsp;&nbsp;</span>&lt;15&gt;splitlines - 行分割</a></span></li><li><span><a href="#<16>isalpha-&amp;-isdigit-&amp;-isalnum-&amp;-isspace" data-toc-modified-id="<16>isalpha-&amp;-isdigit-&amp;-isalnum-&amp;-isspace-16.1.16"><span class="toc-item-num">16.1.16&nbsp;&nbsp;</span>&lt;16&gt;isalpha &amp; isdigit &amp; isalnum &amp; isspace</a></span></li><li><span><a href="#<17>join---重点" data-toc-modified-id="<17>join---重点-16.1.17"><span class="toc-item-num">16.1.17&nbsp;&nbsp;</span>&lt;17&gt;join - 重点</a></span></li></ul></li><li><span><a href="#list" data-toc-modified-id="list-16.2"><span class="toc-item-num">16.2&nbsp;&nbsp;</span>list</a></span><ul class="toc-item"><li><span><a href="#<1>-添加元素" data-toc-modified-id="<1>-添加元素-16.2.1"><span class="toc-item-num">16.2.1&nbsp;&nbsp;</span>&lt;1&gt; 添加元素</a></span></li><li><span><a href="#<2>-修改元素" data-toc-modified-id="<2>-修改元素-16.2.2"><span class="toc-item-num">16.2.2&nbsp;&nbsp;</span>&lt;2&gt; 修改元素</a></span></li><li><span><a href="#<3>-查找元素" data-toc-modified-id="<3>-查找元素-16.2.3"><span class="toc-item-num">16.2.3&nbsp;&nbsp;</span>&lt;3&gt; 查找元素</a></span></li><li><span><a href="#<4>-index--&amp;-count" data-toc-modified-id="<4>-index--&amp;-count-16.2.4"><span class="toc-item-num">16.2.4&nbsp;&nbsp;</span>&lt;4&gt; index  &amp; count</a></span></li><li><span><a href="#<5>-删除元素" data-toc-modified-id="<5>-删除元素-16.2.5"><span class="toc-item-num">16.2.5&nbsp;&nbsp;</span>&lt;5&gt; 删除元素</a></span></li><li><span><a href="#<6>-排序" data-toc-modified-id="<6>-排序-16.2.6"><span class="toc-item-num">16.2.6&nbsp;&nbsp;</span>&lt;6&gt; 排序</a></span></li><li><span><a href="#<7>-列表嵌套" data-toc-modified-id="<7>-列表嵌套-16.2.7"><span class="toc-item-num">16.2.7&nbsp;&nbsp;</span>&lt;7&gt; 列表嵌套</a></span></li></ul></li><li><span><a href="#元组" data-toc-modified-id="元组-16.3"><span class="toc-item-num">16.3&nbsp;&nbsp;</span>元组</a></span></li><li><span><a href="#字典" data-toc-modified-id="字典-16.4"><span class="toc-item-num">16.4&nbsp;&nbsp;</span>字典</a></span><ul class="toc-item"><li><span><a href="#<1>-查看元素" data-toc-modified-id="<1>-查看元素-16.4.1"><span class="toc-item-num">16.4.1&nbsp;&nbsp;</span>&lt;1&gt; 查看元素</a></span></li><li><span><a href="#<2>-修改元素" data-toc-modified-id="<2>-修改元素-16.4.2"><span class="toc-item-num">16.4.2&nbsp;&nbsp;</span>&lt;2&gt; 修改元素</a></span></li><li><span><a href="#<3>-添加元素" data-toc-modified-id="<3>-添加元素-16.4.3"><span class="toc-item-num">16.4.3&nbsp;&nbsp;</span>&lt;3&gt; 添加元素</a></span></li><li><span><a href="#<4>-删除元素" data-toc-modified-id="<4>-删除元素-16.4.4"><span class="toc-item-num">16.4.4&nbsp;&nbsp;</span>&lt;4&gt; 删除元素</a></span></li><li><span><a href="#<5>-len()" data-toc-modified-id="<5>-len()-16.4.5"><span class="toc-item-num">16.4.5&nbsp;&nbsp;</span>&lt;5&gt; len()</a></span></li><li><span><a href="#<6>-keys" data-toc-modified-id="<6>-keys-16.4.6"><span class="toc-item-num">16.4.6&nbsp;&nbsp;</span>&lt;6&gt; keys</a></span></li><li><span><a href="#<7>-values" data-toc-modified-id="<7>-values-16.4.7"><span class="toc-item-num">16.4.7&nbsp;&nbsp;</span>&lt;7&gt; values</a></span></li><li><span><a href="#<8>-items" data-toc-modified-id="<8>-items-16.4.8"><span class="toc-item-num">16.4.8&nbsp;&nbsp;</span>&lt;8&gt; items</a></span></li></ul></li><li><span><a href="#总结" data-toc-modified-id="总结-16.5"><span class="toc-item-num">16.5&nbsp;&nbsp;</span>总结</a></span></li></ul></li><li><span><a href="#函数" data-toc-modified-id="函数-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>函数</a></span><ul class="toc-item"><li><span><a href="#函数文档说明" data-toc-modified-id="函数文档说明-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>函数文档说明</a></span></li><li><span><a href="#函数参数" data-toc-modified-id="函数参数-17.2"><span class="toc-item-num">17.2&nbsp;&nbsp;</span>函数参数</a></span><ul class="toc-item"><li><span><a href="#定义带有参数的函数" data-toc-modified-id="定义带有参数的函数-17.2.1"><span class="toc-item-num">17.2.1&nbsp;&nbsp;</span>定义带有参数的函数</a></span></li><li><span><a href="#调用带有参数的函数" data-toc-modified-id="调用带有参数的函数-17.2.2"><span class="toc-item-num">17.2.2&nbsp;&nbsp;</span>调用带有参数的函数</a></span></li><li><span><a href="#调用函数时参数的顺序" data-toc-modified-id="调用函数时参数的顺序-17.2.3"><span class="toc-item-num">17.2.3&nbsp;&nbsp;</span>调用函数时参数的顺序</a></span></li><li><span><a href="#函数返回值" data-toc-modified-id="函数返回值-17.2.4"><span class="toc-item-num">17.2.4&nbsp;&nbsp;</span>函数返回值</a></span></li><li><span><a href="#函数类型" data-toc-modified-id="函数类型-17.2.5"><span class="toc-item-num">17.2.5&nbsp;&nbsp;</span>函数类型</a></span></li><li><span><a href="#函数的嵌套" data-toc-modified-id="函数的嵌套-17.2.6"><span class="toc-item-num">17.2.6&nbsp;&nbsp;</span>函数的嵌套</a></span></li><li><span><a href="#局部变量和全局变量" data-toc-modified-id="局部变量和全局变量-17.2.7"><span class="toc-item-num">17.2.7&nbsp;&nbsp;</span>局部变量和全局变量</a></span></li><li><span><a href="#多个返回值(newB)" data-toc-modified-id="多个返回值(newB)-17.2.8"><span class="toc-item-num">17.2.8&nbsp;&nbsp;</span>多个返回值(newB)</a></span></li><li><span><a href="#参数" data-toc-modified-id="参数-17.2.9"><span class="toc-item-num">17.2.9&nbsp;&nbsp;</span>参数</a></span><ul class="toc-item"><li><span><a href="#缺省参数" data-toc-modified-id="缺省参数-17.2.9.1"><span class="toc-item-num">17.2.9.1&nbsp;&nbsp;</span>缺省参数</a></span></li><li><span><a href="#不定长参数" data-toc-modified-id="不定长参数-17.2.9.2"><span class="toc-item-num">17.2.9.2&nbsp;&nbsp;</span>不定长参数</a></span></li><li><span><a href="#参数引用" data-toc-modified-id="参数引用-17.2.9.3"><span class="toc-item-num">17.2.9.3&nbsp;&nbsp;</span>参数引用</a></span></li></ul></li><li><span><a href="#引用测试" data-toc-modified-id="引用测试-17.2.10"><span class="toc-item-num">17.2.10&nbsp;&nbsp;</span>引用测试</a></span></li><li><span><a href="#递归函数" data-toc-modified-id="递归函数-17.2.11"><span class="toc-item-num">17.2.11&nbsp;&nbsp;</span>递归函数</a></span></li><li><span><a href="#lambda函数/匿名函数" data-toc-modified-id="lambda函数/匿名函数-17.2.12"><span class="toc-item-num">17.2.12&nbsp;&nbsp;</span>lambda函数/匿名函数</a></span></li></ul></li></ul></li><li><span><a href="#文件" data-toc-modified-id="文件-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>文件</a></span><ul class="toc-item"><li><span><a href="#<1>-打开文件" data-toc-modified-id="<1>-打开文件-18.1"><span class="toc-item-num">18.1&nbsp;&nbsp;</span>&lt;1&gt; 打开文件</a></span></li><li><span><a href="#<2>-关闭文件" data-toc-modified-id="<2>-关闭文件-18.2"><span class="toc-item-num">18.2&nbsp;&nbsp;</span>&lt;2&gt; 关闭文件</a></span></li><li><span><a href="#<3>-文件的读和写" data-toc-modified-id="<3>-文件的读和写-18.3"><span class="toc-item-num">18.3&nbsp;&nbsp;</span>&lt;3&gt; 文件的读和写</a></span><ul class="toc-item"><li><span><a href="#写数据" data-toc-modified-id="写数据-18.3.1"><span class="toc-item-num">18.3.1&nbsp;&nbsp;</span>写数据</a></span></li><li><span><a href="#读数据(read)" data-toc-modified-id="读数据(read)-18.3.2"><span class="toc-item-num">18.3.2&nbsp;&nbsp;</span>读数据(read)</a></span></li><li><span><a href="#读数据(readlines)" data-toc-modified-id="读数据(readlines)-18.3.3"><span class="toc-item-num">18.3.3&nbsp;&nbsp;</span>读数据(readlines)</a></span></li><li><span><a href="#读数据(readline）" data-toc-modified-id="读数据(readline）-18.3.4"><span class="toc-item-num">18.3.4&nbsp;&nbsp;</span>读数据(readline）</a></span></li><li><span><a href="#制作文件备份" data-toc-modified-id="制作文件备份-18.3.5"><span class="toc-item-num">18.3.5&nbsp;&nbsp;</span>制作文件备份</a></span></li><li><span><a href="#文件的定位读写" data-toc-modified-id="文件的定位读写-18.3.6"><span class="toc-item-num">18.3.6&nbsp;&nbsp;</span>文件的定位读写</a></span><ul class="toc-item"><li><span><a href="#<1>-获取当前读写的位置-tell()" data-toc-modified-id="<1>-获取当前读写的位置-tell()-18.3.6.1"><span class="toc-item-num">18.3.6.1&nbsp;&nbsp;</span>&lt;1&gt; 获取当前读写的位置 tell()</a></span></li><li><span><a href="#<2>定位到某个位置-seek()" data-toc-modified-id="<2>定位到某个位置-seek()-18.3.6.2"><span class="toc-item-num">18.3.6.2&nbsp;&nbsp;</span>&lt;2&gt;定位到某个位置 seek()</a></span></li></ul></li></ul></li><li><span><a href="#文件相关操作" data-toc-modified-id="文件相关操作-18.4"><span class="toc-item-num">18.4&nbsp;&nbsp;</span>文件相关操作</a></span></li><li><span><a href="#批量修改文件名称" data-toc-modified-id="批量修改文件名称-18.5"><span class="toc-item-num">18.5&nbsp;&nbsp;</span>批量修改文件名称</a></span></li></ul></li><li><span><a href="#面向对象" data-toc-modified-id="面向对象-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>面向对象</a></span><ul class="toc-item"><li><span><a href="#类的构成" data-toc-modified-id="类的构成-19.1"><span class="toc-item-num">19.1&nbsp;&nbsp;</span>类的构成</a></span></li><li><span><a href="#定义类" data-toc-modified-id="定义类-19.2"><span class="toc-item-num">19.2&nbsp;&nbsp;</span>定义类</a></span></li><li><span><a href="#创建对象" data-toc-modified-id="创建对象-19.3"><span class="toc-item-num">19.3&nbsp;&nbsp;</span>创建对象</a></span></li><li><span><a href="#self" data-toc-modified-id="self-19.4"><span class="toc-item-num">19.4&nbsp;&nbsp;</span>self</a></span></li><li><span><a href="#魔法函数init" data-toc-modified-id="魔法函数init-19.5"><span class="toc-item-num">19.5&nbsp;&nbsp;</span>魔法函数init</a></span></li><li><span><a href="#魔法函数str" data-toc-modified-id="魔法函数str-19.6"><span class="toc-item-num">19.6&nbsp;&nbsp;</span>魔法函数str</a></span></li><li><span><a href="#面向对象-属性" data-toc-modified-id="面向对象-属性-19.7"><span class="toc-item-num">19.7&nbsp;&nbsp;</span>面向对象-属性</a></span></li><li><span><a href="#魔法函数del" data-toc-modified-id="魔法函数del-19.8"><span class="toc-item-num">19.8&nbsp;&nbsp;</span>魔法函数del</a></span></li><li><span><a href="#单继承" data-toc-modified-id="单继承-19.9"><span class="toc-item-num">19.9&nbsp;&nbsp;</span>单继承</a></span></li><li><span><a href="#多继承" data-toc-modified-id="多继承-19.10"><span class="toc-item-num">19.10&nbsp;&nbsp;</span>多继承</a></span></li><li><span><a href="#重写父类" data-toc-modified-id="重写父类-19.11"><span class="toc-item-num">19.11&nbsp;&nbsp;</span>重写父类</a></span></li><li><span><a href="#调用父类" data-toc-modified-id="调用父类-19.12"><span class="toc-item-num">19.12&nbsp;&nbsp;</span>调用父类</a></span></li><li><span><a href="#多态" data-toc-modified-id="多态-19.13"><span class="toc-item-num">19.13&nbsp;&nbsp;</span>多态</a></span></li><li><span><a href="#类的属性" data-toc-modified-id="类的属性-19.14"><span class="toc-item-num">19.14&nbsp;&nbsp;</span>类的属性</a></span></li><li><span><a href="#静态方法和类方法" data-toc-modified-id="静态方法和类方法-19.15"><span class="toc-item-num">19.15&nbsp;&nbsp;</span>静态方法和类方法</a></span><ul class="toc-item"><li><span><a href="#类方法" data-toc-modified-id="类方法-19.15.1"><span class="toc-item-num">19.15.1&nbsp;&nbsp;</span>类方法</a></span></li><li><span><a href="#静态方法" data-toc-modified-id="静态方法-19.15.2"><span class="toc-item-num">19.15.2&nbsp;&nbsp;</span>静态方法</a></span></li></ul></li><li><span><a href="#异常" data-toc-modified-id="异常-19.16"><span class="toc-item-num">19.16&nbsp;&nbsp;</span>异常</a></span><ul class="toc-item"><li><span><a href="#魔法函数new" data-toc-modified-id="魔法函数new-19.16.1"><span class="toc-item-num">19.16.1&nbsp;&nbsp;</span>魔法函数new</a></span></li><li><span><a href="#单例模式" data-toc-modified-id="单例模式-19.16.2"><span class="toc-item-num">19.16.2&nbsp;&nbsp;</span>单例模式</a></span></li><li><span><a href="#捕获异常" data-toc-modified-id="捕获异常-19.16.3"><span class="toc-item-num">19.16.3&nbsp;&nbsp;</span>捕获异常</a></span></li><li><span><a href="#抛出自定义的异常" data-toc-modified-id="抛出自定义的异常-19.16.4"><span class="toc-item-num">19.16.4&nbsp;&nbsp;</span>抛出自定义的异常</a></span></li><li><span><a href="#异常处理中抛出异常" data-toc-modified-id="异常处理中抛出异常-19.16.5"><span class="toc-item-num">19.16.5&nbsp;&nbsp;</span>异常处理中抛出异常</a></span></li></ul></li><li><span><a href="#模块" data-toc-modified-id="模块-19.17"><span class="toc-item-num">19.17&nbsp;&nbsp;</span>模块</a></span><ul class="toc-item"><li><span><a href="#自制模块" data-toc-modified-id="自制模块-19.17.1"><span class="toc-item-num">19.17.1&nbsp;&nbsp;</span>自制模块</a></span></li><li><span><a href="#魔法函数main" data-toc-modified-id="魔法函数main-19.17.2"><span class="toc-item-num">19.17.2&nbsp;&nbsp;</span>魔法函数main</a></span></li><li><span><a href="#魔法函数all" data-toc-modified-id="魔法函数all-19.17.3"><span class="toc-item-num">19.17.3&nbsp;&nbsp;</span>魔法函数all</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 操作系统(科普章节)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 没有安装操作系统的计算机，通常被称为 **裸机**
#
# 如果想在 **裸机** 上运行自己所编写的程序，就必须用机器语言书写程序
# 如果计算机上安装了操作系统，就可以在操作系统上安装支持的高级语言环境，用高级语言开发程序

# %% [markdown]
# **操作系统的作用**
#
# 是现代计算机系统中**最基本和最重要**的系统软件
#
# 是配置在计算机硬件上的**第一层软件**，是对硬件系统的**首次扩展**
#
# 主要作用是管理好硬件设备，并为用户和应用程序提供一个简单的**接口**，以便于使用
#
# 而其它的诸如编译程序、数据库管理系统，以及大量的应用软件，都直接依赖于操作系统的支持

# %% [markdown]
# # Python的关键点常识

# %% [markdown]
# * Python的发音与拼写
# * Python的意思是蟒蛇，源于作者喜欢的一部电视剧
# * Python的作者是Guido van Rossum（龟叔）
# * Python是龟叔在1989年圣诞节期间，为了打发无聊的圣诞节而用C编写的一个编程语言
# * Python正式诞生于1991年
# * Python的解释器如今有多个语言实现，我们常用的是CPython（官方版本的C语言实现），其他还有Jython（可以运行在Java平台）、IronPython（可以运行在.NET和Mono平台）、PyPy（Python实现的，支持JIT即时编译）
# * Python目前有两个版本，Python2和Python3，最新版分别为2.7.12和3.5.2，现阶段大部分公司用的是Python2
# * Life is shot, you need Python. 人生苦短，我用Python。

# %% [markdown]
# # Python优点和缺点

# %% [markdown]
# ##  优点

# %% [markdown]
# * **简单**
#
#     ————Python是一种代表简单主义思想的语言。阅读一个良好的Python程序就感觉像是在读英语一样，尽管这个英语的要求非常严格！Python的这种伪代码本质是它最大的优点之一。它使你能够专注于解决问题而不是去搞明白语言本身。
#
#
# * **易学**
#
#     ————就如同你即将看到的一样，Python极其容易上手。前面已经提到了，Python有极其简单的语法。
#
# * **免费/开源**
#
#     ————Python是FLOSS（自由/开放源码软件）之一。简单地说，你可以自由地发布这个软件的拷贝、阅读它的源代码、对它做改动、把它的一部分用于新的自由软件中。FLOSS是基于一个团体分享知识的概念。这是为什么Python如此优秀的原因之一——它是由一群希望看到一个更加优秀的Python的人创造并经常改进着的。
#
# * **高层语言**
#
#     ————当你用Python语言编写程序的时候，你无需考虑诸如如何管理你的程序使用的内存一类的底层细节。
#
# * **可移植性**
#
#     ————由于它的开源本质，Python已经被移植在许多平台上（经过改动使它能够工作在不同平台上）。如果你小心地避免使用依赖于系统的特性，那么你的所有Python程序无需修改就可以在下述任何平台上面运行。这些平台包括Linux、Windows、FreeBSD、Macintosh、Solaris、OS/2、Amiga、AROS、AS/400、BeOS、OS/390、z/OS、Palm OS、QNX、VMS、Psion、Acom RISC OS、VxWorks、PlayStation、Sharp Zaurus、Windows CE甚至还有PocketPC、Symbian以及Google基于linux开发的Android平台！
#
# * **解释性**
#
#     ————这一点需要一些解释。一个用编译性语言比如C或C++写的程序可以从源文件（即C或C++语言）转换到一个你的计算机使用的语言（二进制代码，即0和1）。这个过程通过编译器和不同的标记、选项完成。当你运行你的程序的时候，连接/转载器软件把你的程序从硬盘复制到内存中并且运行。而Python语言写的程序不需要编译成二进制代码。你可以直接从源代码运行程序。在计算机内部，Python解释器把源代码转换成称为字节码的中间形式，然后再把它翻译成计算机使用的机器语言并运行。事实上，由于你不再需要担心如何编译程序，如何确保连接转载正确的库等等，所有这一切使得使用Python更加简单。由于你只需要把你的Python程序拷贝到另外一台计算机上，它就可以工作了，这也使得你的Python程序更加易于移植。
#
# * **面向对象**
#
#     ————Python既支持面向过程的编程也支持面向对象的编程。在“面向过程”的语言中，程序是由过程或仅仅是可重用代码的函数构建起来的。在“面向对象”的语言中，程序是由数据和功能组合而成的对象构建起来的。与其他主要的语言如C++和Java相比，Python以一种非常强大又简单的方式实现面向对象编程。
#
# * **可扩展性**
#
#     ————如果你需要你的一段关键代码运行得更快或者希望某些算法不公开，你可以把你的部分程序用C或C++编写，然后在你的Python程序中使用它们。
#
# * **丰富的库**
#
#     ————Python标准库确实很庞大。它可以帮助你处理各种工作，包括正则表达式、文档生成、单元测试、线程、数据库、网页浏览器、CGI、FTP、电子邮件、XML、XML-RPC、HTML、WAV文件、密码系统、GUI（图形用户界面）、Tk和其他与系统有关的操作。记住，只要安装了Python，所有这些功能都是可用的。这被称作Python的“功能齐全”理念。除了标准库以外，还有许多其他高质量的库，如wxPython、Twisted和Python图像库等等。
#
# * **规范的代码**
#
#      ————Python采用强制缩进的方式使得代码具有极佳的可读性。

# %% [markdown]
# ## 缺点

# %% [markdown]
# 1.运行速度，有速度要求的话，用C++改写关键部分吧。
#
# 2.国内市场较小（国内以python来做主要开发的，目前只有一些web2.0公司）。但时间推移，目前很多国内软件公司，尤其是游戏公司，也开始规模使用他。
#
# 3.中文资料匮乏（好的python中文资料屈指可数）。托社区的福，有几本优秀的教材已经被翻译了，但入门级教材多，高级内容还是只能看英语版。
#
# 4.构架选择太多（没有像C#这样的官方.net构架，也没有像ruby由于历史较短，构架开发的相对集中。Ruby on Rails 构架开发中小型web程序天下无敌）。不过这也从另一个侧面说明，python比较优秀，吸引的人才多，项目也多。

# %% [markdown]
# # 应用场景

# %% [markdown]
# * **Web应用开发**
#
# Python经常被用于Web开发。比如，通过mod_wsgi模块，Apache可以运行用Python编写的Web程序。Python定义了WSGI标准应用接口来协调Http服务器与基于Python的Web程序之间的通信。一些Web框架，如Django,TurboGears,web2py,Zope等，可以让程序员轻松地开发和管理复杂的Web程序。
#
# * **操作系统管理、服务器运维的自动化脚本**
#
# 在很多操作系统里，Python是标准的系统组件。 大多数Linux发行版以及NetBSD、OpenBSD和Mac OS X都集成了Python，可以在终端下直接运行Python。有一些Linux发行版的安装器使用Python语言编写，比如Ubuntu的Ubiquity安装器,Red Hat Linux和Fedora的Anaconda安装器。Gentoo Linux使用Python来编写它的Portage包管理系统。Python标准库包含了多个调用操作系统功能的库。通过pywin32这个第三方软件 包，Python能够访问Windows的COM服务及其它Windows API。使用IronPython，Python程序能够直接调用.Net Framework。一般说来，Python编写的系统管理脚本在可读性、性能、代码重用度、扩展性几方面都优于普通的shell脚本。
#
# * **科学计算**
#
# NumPy,SciPy,Matplotlib可以让Python程序员编写科学计算程序。
#
# * **桌面软件**
#
# PyQt、PySide、wxPython、PyGTK是Python快速开发桌面应用程序的利器。
#
# * **服务器软件（网络软件）**
#
# Python对于各种网络协议的支持很完善，因此经常被用于编写服务器软件、网络爬虫。第三方库Twisted支持异步网络编程和多数标准的网络协议(包含客户端和服务器)，并且提供了多种工具，被广泛用于编写高性能的服务器软件。
#
# * **游戏**
#
# 很多游戏使用C++编写图形显示等高性能模块，而使用Python或者Lua编写游戏的逻辑、服务器。相较于Python，Lua的功能更简单、体积更小；而Python则支持更多的特性和数据类型。
#
# * **构思实现，产品早期原型和迭代**
#
# YouTube、Google、Yahoo!、NASA都在内部大量地使用Python。

# %% [markdown]
# # 注释

# %% [markdown]
# ## 单行注释

# %%
# 我是注释，可以在里写一些功能说明之类的哦
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## 多行注释

# %%
'''
我是多行注释，可以写很多很多行的功能说明
这就是我newB之处
哈哈哈。。。
'''
# Out:
# '\n我是多行注释，可以写很多很多行的功能说明\n这就是我newB之处\n哈哈哈。。。\n'

# %%
print('你好')
# Out:
# 你好

# %% [markdown]
# ## 中文支持

# %%
# 在python中规范的使用方式
# -*- coding:utf-8 -*-

# %% [markdown]
# # 变量及类型

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 标识符

# %% [markdown]
# ## 什么是标识符？

# %% [markdown]
# 标识符是自己定义的，如变量名、函数名、类名等等

# %% [markdown]
# ## 标识符命名规则

# %% [markdown]
# * 标示符由字母、下划线和数字组成，且数字不能开头
# * 区分大小写

# %% [markdown]
# ## 标识符书写

# %% [markdown]
# * 见名知意
#
#     比如 name student Person

# %% [markdown]
# * 命名方法
#     * 驼峰法 比如studentName
#     * 小驼峰式命名法（lower camel case）：第一个单词以小写字母开始 比如myName
#     * 大驼峰式命名法（upper camel case）： 每一个单字的首字母都采用大写字母 比如MyName FisrtName
#     * 连接命名法 比如my_name student_name

# %% [markdown]
# # 关键字

# %%
import keyword

all_keywords_list = list(keyword.kwlist)
for x in all_keywords_list:
    print(x, end='\n')
    
print(len(all_keywords_list))
# Out:
# False
# None
# True
# __peg_parser__
# and
# as
# assert
# async
# await
# break
# class
# continue
# def
# del
# elif
# else
# except
# finally
# for
# from
# global
# if
# import
# in
# is
# lambda
# nonlocal
# not
# or
# pass
# raise
# return
# try
# while
# with
# yield
# 36

# %% [markdown]
# # 输入与输出

# %% [markdown]
# ## 输出

# %%
# 打印提示
print('hello world')
print('给我的卡---印度语，你好的意思')
# Out:
# hello world
# 给我的卡---印度语，你好的意思

# %%
age = 10
print("我今年%d岁"%age)

age += 1
print("我今年%d岁"%age)

age += 1
print("我今年%d岁"%age)
# Out:
# 我今年10岁
# 我今年11岁
# 我今年12岁

# %%
age = 18
name = "xiaohua"
print("我的姓名是%s,年龄是%d"%(name,age))
# Out:
# 我的姓名是xiaohua,年龄是18

# %% [markdown]
# ## 格式符号

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("1234567890-------") # 会在一行显示

print("1234567890\n-------") # 一行显示1234567890，另外一行显示-------
# Out:
# 1234567890-------
# 1234567890
# -------

# %% [markdown]
# ## 输入

# %%
a = input()
print(a)
# Out:
# 1314
# 1314

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
x = input("请输入密码：")
print("所输入的密码是：", x)
# Out:
# 请输入密码：1314
# 所输入的密码是： 1314

# %% [markdown]
# # 运算符

# %% [markdown]
# ## 算术运算符

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a = 10
b = 20
print(a - b)
# Out:
# -10

# %%
a = 10
b = 20
print(10 * 20)
# Out:
# 200

# %%
a = 10
b = 20
c = 20.0
print(b / a)
print(c / a)
# Out:
# 2.0
# 2.0

# %%
x = 5
y = 2
print(x % y)
# Out:
# 1

# %%
x = 2
n = 10
print(x ** n)
# Out:
# 1024

# %%
x = 9
y = 2
print(x / y)
print(x // y)
# Out:
# 4.5
# 4

# %% [markdown]
# ## 赋值运算符

# %%
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
a, b, c = 1, 2, 3
print(a,b,c)
# Out:
# 1 2 3

# %%
print('you','me','him') # 可以发现，打印出来的内容自动空格
# Out:
# you me him

# %% [markdown]
# ## 复合赋值运算符

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 数据类型转换

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = '123'
print(a)
print(type(a))
# Out:
# 123
# <class 'str'>

# %%
b = int(a)
print(b)
print(type(b))
# Out:
# 123
# <class 'int'>

# %% [markdown]
# # 判断语句

# %% [markdown]
# ## if-else

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
chePiao = 1 # 用1代表有车票，0代表没有车票
if chePiao == 1:
    print("有车票，可以上火车")
    print("终于可以见到Ta了，美滋滋~~~")
else:
    print("没有车票，不能上车")
    print("亲爱的，那就下次见了，一票难求啊~~~~(>_<)~~~~")
# Out:
# 有车票，可以上火车
# 终于可以见到Ta了，美滋滋~~~

# %% [markdown]
# ## elif

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = 77

if score>=90 and score<=100:
    print('本次考试，等级为A')
elif score>=80 and score<90:
    print('本次考试，等级为B')
elif score>=70 and score<80:
    print('本次考试，等级为C')
elif score>=60 and score<70:
    print('本次考试，等级为D')
elif score>=0 and score<60:
    print('本次考试，等级为E')
# Out:
# 本次考试，等级为C

# %% [markdown]
# ## if嵌套

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
chePiao = 1     # 用1代表有车票，0代表没有车票
daoLenght = 9     # 刀子的长度，单位为cm

if chePiao == 1:
    print("有车票，可以进站")
    if daoLenght < 10:
        print("通过安检")
        print("终于可以见到Ta了，美滋滋~~~")
    else:
        print("没有通过安检")
        print("刀子的长度超过规定，等待警察处理...")
else:
    print("没有车票，不能进站")
    print("亲爱的，那就下次见了，一票难求啊~~~~(>_<)~~~~")
# Out:
# 有车票，可以进站
# 通过安检
# 终于可以见到Ta了，美滋滋~~~

# %% [markdown]
# ## 猜拳游戏

# %%
import random

player = input('请输入：剪刀(0)  石头(1)  布(2):')

player = int(player)

computer = random.randint(0,2)

# 用来进行测试
#print('player=%d,computer=%d',(player,computer))

if ((player == 0) and (computer == 2)) or ((player ==1) and (computer == 0)) or ((player == 2) and (computer == 1)):
    print('获胜，哈哈，你太厉害了')
elif player == computer:
    print('平局，要不再来一局')
else:
    print('输了，不要走，洗洗手接着来，决战到天亮')
# Out:
# 请输入：剪刀(0)  石头(1)  布(2):1
# 输了，不要走，洗洗手接着来，决战到天亮

# %% [markdown]
# # 比较运算符/关系运算符

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 逻辑运算符

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 循环语句

# %%
i = 0
while i<10:
    print("媳妇儿，我错了")
    i = i + 1
print('i = ', i)
# Out:
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# 媳妇儿，我错了
# i =  10

# %% [markdown]
# ## while循环

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = 0
while i<5:
    print("当前是第%d次执行循环"%(i+1))
    print("i=%d"%i)
    i+=1
# Out:
# 当前是第1次执行循环
# i=0
# 当前是第2次执行循环
# i=1
# 当前是第3次执行循环
# i=2
# 当前是第4次执行循环
# i=3
# 当前是第5次执行循环
# i=4

# %% [markdown]
# ## 1-100求和

# %%
#encoding=utf-8

i = 1
sum = 0
while i<=100:
    sum = sum + i
    i += 1

print("1~100的累积和为:%d"%sum)
# Out:
# 1~100的累积和为:5050

# %% [markdown]
# ## 1-100偶数求和

# %%
#encoding=utf-8

i = 1
sum = 0
while i<=100:
    if i%2 == 0:
        sum = sum + i
    i+=1

print("1~100的累积和为:%d"%sum)
# Out:
# 1~100的累积和为:2550

# %% [markdown]
# ## break

# %% [markdown]
# **break的作用：用来结束整个循环**

# %%
name = 'dongGe'

for x in name:
  print('----')
  print(x)
# Out:
# ----
# d
# ----
# o
# ----
# n
# ----
# g
# ----
# G
# ----
# e

# %%
name = 'dongGe'

for x in name:
  print('----')
  if x == 'g': 
      break
  print(x)
# Out:
# ----
# d
# ----
# o
# ----
# n
# ----

# %%
name = 'dongGe'

for x in name:
  print('----')
  print(x)
  if x == 'g': 
      break
# Out:
# ----
# d
# ----
# o
# ----
# n
# ----
# g

# %% [markdown]
# ## continue

# %% [markdown]
# **continue的作用：用来结束本次循环，紧接着执行下一次的循环**

# %%
name = 'dongGe'

for x in name:
  print('----')
  if x == 'g': 
      continue
  print(x)
# Out:
# ----
# d
# ----
# o
# ----
# n
# ----
# ----
# G
# ----
# e

# %% [markdown]
# ## 总结

# %% [markdown]
# * **break/continue只能用在循环中，除此以外不能单独使用**
#
# * **break/continue在嵌套循环中，只对最近的一层循环起作用**

# %% [markdown]
# ## 99乘法表

# %%
i = 1
while i<=9:
    j=1
    while j<=i:
        print("%d*%d=%-2d "%(j,i,i*j),end='')
        j+=1
    print('\n')
    i+=1
# Out:
# 1*1=1
#
# 1*2=2  2*2=4
#
# 1*3=3  2*3=6  3*3=9
#
# 1*4=4  2*4=8  3*4=12 4*4=16
#
# 1*5=5  2*5=10 3*5=15 4*5=20 5*5=25
#
# 1*6=6  2*6=12 3*6=18 4*6=24 5*6=30 6*6=36
#
# 1*7=7  2*7=14 3*7=21 4*7=28 5*7=35 6*7=42 7*7=49
#
# 1*8=8  2*8=16 3*8=24 4*8=32 5*8=40 6*8=48 7*8=56 8*8=64
#
# 1*9=9  2*9=18 3*9=27 4*9=36 5*9=45 6*9=54 7*9=63 8*9=72 9*9=81

# %% [markdown]
# ## for循环

# %%
for x in 'hello':
    print(x,end=' ')
# Out:
# h e l l o

# %% [markdown]
# # 数据类型

# %% [markdown]
# ## string

# %%
name = 'xiaoming'
position = '讲师'
address = '北京市昌平区建材城西路金燕龙办公楼1层'

print('--------------------------------------------------')
print("姓名：%s"%name)
print("职位：%s"%position)
print("公司地址：%s"%address)
print('--------------------------------------------------')
# Out:
# --------------------------------------------------
# 姓名：xiaoming
# 职位：讲师
# 公司地址：北京市昌平区建材城西路金燕龙办公楼1层
# --------------------------------------------------

# %%
x = 'abcdef'
print(x[:2])
# Out:
# ab

# %%
print(x[::2])
# Out:
# ace

# %%
print(x[1:5:2])
# Out:
# bd

# %%
print(x[0:5])
# Out:
# abcde

# %%
print(x[0:-1])
# Out:
# abcde

# %% [markdown]
# ### <1>find & rfind

# %%
mystr = 'hello,world,I am Dr.Lee'
indexnum = mystr.find('I')
print(indexnum)

indexnumx = mystr.find('i')
print(indexnumx)
# Out:
# 12
# -1

# %% [markdown]
# ### <2>index & rindex

# %%
mystr = 'hello,world,I am Dr.Lee'
indexnum = mystr.index('I')
print(indexnum)

# indexnumx = mystr.index('i') # 找不到报错？
# print(indexnumx)
# Out:
# 12

# %% [markdown]
# ### <3>count

# %%
mystr = 'hello,world,I am Dr.Lee'
count_num = mystr.count('e')
print(count_num)
# Out:
# 3

# %% [markdown]
# ### <4>replace

# %%
mystr = 'you should hahaha everyday.'
mystr.replace('ha','HA')
print(mystr.replace('ha','HA'))
print(mystr)
# Out:
# you should HAHAHA everyday.
# you should hahaha everyday.

# %% [markdown]
# ### <5>split

# %%
mystr = 'The world is ha ha ha'
list_mystr = mystr.split(' ')
print(list_mystr)
# Out:
# ['The', 'world', 'is', 'ha', 'ha', 'ha']

# %% [markdown]
# ### <6>capitalize

# %%
mystr = 'i love you'
print(mystr.capitalize()) # 大写首字母
# Out:
# I love you

# %%
mystr = 'i love you.'
print(mystr.title()) # 大写每个单词的首字母
# Out:
# I Love You.

# %% [markdown]
# ### <7>startswith

# %%
mystr = 'hello world, this is python'
print(mystr.startswith('he'))
# Out:
# True

# %%
print(mystr.startswith('hell'))
# Out:
# True

# %% [markdown]
# ### <8>endswith

# %%
mystr = 'hello world, this is python'
print(mystr.endswith('on'))
# Out:
# True

# %% [markdown]
# ### <9>lower

# %%
mystr = 'Hello,WORLD'
print(mystr.lower())
print(mystr)
# Out:
# hello,world
# Hello,WORLD

# %% [markdown]
# ### <10>upper

# %%
mystr = 'Hello,WORLD'
print(mystr.upper())
print(mystr)
# Out:
# HELLO,WORLD
# Hello,WORLD

# %% [markdown]
# ### <11>ljust & rjust

# %%
mystr = 'hello'
print(mystr.ljust(10))
print(mystr.rjust(10))
# Out:
# hello
#      hello

# %% [markdown]
# ### <12>center

# %%
mystr = 'this'
print(mystr.center(10))
# Out:
#    this

# %% [markdown]
# ### <13>lstrip & rstrip & strip

# %%
mystr = '   haha   '
print(mystr.lstrip())
# Out:
# haha

# %%
print(mystr.rstrip())
# Out:
#    haha

# %%
print(mystr.strip())
# Out:
# haha

# %% [markdown]
# ### <14>partition & rpartition

# %%
mystr = 'hello world ha ha i p q'
print(mystr.partition('ha')) # 分割
# Out:
# ('hello world ', 'ha', ' ha i p q')

# %%
mystr = 'hello world ha ha i p q'
print(mystr.rpartition('ha')) # 分割
# Out:
# ('hello world ha ', 'ha', ' i p q')

# %% [markdown]
# ### <15>splitlines - 行分割

# %%
mystr = 'hello\nworld'
print(mystr)
# Out:
# hello
# world

# %%
print(mystr.splitlines())
# Out:
# ['hello', 'world']

# %% [markdown]
# ### <16>isalpha & isdigit & isalnum & isspace

# %%
mystr = 'abc'
x = mystr.isalpha()
print(x)
# Out:
# True

# %% [markdown]
# ### <17>join - 重点

# %%
# 在每个字符后面插入str
my_list = ['my','love','is','you']
print(my_list)
# Out:
# ['my', 'love', 'is', 'you']

# %%
str = '$$$'
print(str)

print(my_list)

print(str.join(my_list))
# Out:
# $$$
# ['my', 'love', 'is', 'you']
# my$$$love$$$is$$$you

# %% [markdown]
# ## list

# %%
namesList = ['xiaoWang','xiaoZhang','xiaoHua']
print(namesList)
# Out:
# ['xiaoWang', 'xiaoZhang', 'xiaoHua']

# %%
namesList = ['xiaoWang','xiaoZhang','xiaoHua']
print(namesList[0])
print(namesList[1])
print(namesList[2])
# Out:
# xiaoWang
# xiaoZhang
# xiaoHua

# %%
namesList = ['xiaoWang','xiaoZhang','xiaoHua']
for name in namesList:
    print(name)
# Out:
# xiaoWang
# xiaoZhang
# xiaoHua

# %%
namesList = ['xiaoWang','xiaoZhang','xiaoHua']

length = len(namesList)

i = 0

while i<length:
    print(namesList[i])
    i+=1
# Out:
# xiaoWang
# xiaoZhang
# xiaoHua

# %% [markdown]
# ### <1> 添加元素

# %%
a = [1, 2]
b = [3, 4]
a.append(b)
print(a)
# Out:
# [1, 2, [3, 4]]

# %%
a = [1, 2]
b = [3, 4]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [-1, 10, 4]
a.insert(0, -100)
print(a)
# Out:
# [-100, -1, 10, 4]

# %% [markdown]
# ### <2> 修改元素

# %%
x = [1, 2, 3]
x[-1] = -1
print(x)
# Out:
# [1, 2, -1]

# %% [markdown]
# ### <3> 查找元素

# %%
name_list = ['rose', 'Dr.', 'mike', 'jeson']
print(name_list)
# Out:
# ['rose', 'Dr.', 'mike', 'jeson']

# %%
print('rose' in name_list)
# Out:
# True

# %%
print('Rose' in name_list)
# Out:
# False

# %% [markdown]
# ### <4> index  & count

# %%
x = ['a', 'b', 'c', 'd', 'e', 'f']
y = x.index('a')
print(y)
# Out:
# 0

# %%
y = x.index('c')
print(y)
# Out:
# 2

# %%
y = x.index('a', 0, 3)
print(y)
# Out:
# 0

# %%
y = x.index('a', 1, 3)
print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# k:\WPS_Cloud_Zone\python_jupyter_notebook\Untitled.ipynb Cell 178 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/k%3A/WPS_Cloud_Zone/python_jupyter_notebook/Untitled.ipynb#Y346sZmlsZQ%3D%3D?line=0'>1</a> y = x.index('a', 1, 3)
#       <a href='vscode-notebook-cell:/k%3A/WPS_Cloud_Zone/python_jupyter_notebook/Untitled.ipynb#Y346sZmlsZQ%3D%3D?line=1'>2</a> print(y)
#
# ValueError: 'a' is not in list

# %%
x = ['a', 'c', 'd', 'e', 'a', 'a']
y = x.count('a')
print(y)
# Out:
# 3

# %% [markdown]
# ### <5> 删除元素

# %%
movieName = ['加勒比海盗','骇客帝国','第一滴血','指环王','霍比特人','速度与激情']
print(movieName)
# Out:
# ['加勒比海盗', '骇客帝国', '第一滴血', '指环王', '霍比特人', '速度与激情']

# %%
movieName.pop()
print(movieName)
# Out:
# ['加勒比海盗', '骇客帝国', '第一滴血', '指环王', '霍比特人']

# %%
movieName.remove('加勒比海盗')
print(movieName)
# Out:
# ['骇客帝国', '第一滴血', '指环王', '霍比特人']

# %% [markdown]
# ### <6> 排序

# %%
x = [1, 4, 5, -1, -2, 99]
print(x)
# Out:
# [1, 4, 5, -1, -2, 99]

# %%
x.sort()
print(x)
# Out:
# [-2, -1, 1, 4, 5, 99]

# %%
x = [1, 4, 5, -1, -2, 99]
print(x)
x.sort(reverse=True)
print(x)
# Out:
# [1, 4, 5, -1, -2, 99]
# [99, 5, 4, 1, -1, -2]

# %% [markdown]
# ### <7> 列表嵌套

# %%
schoolNames = [['北京大学','清华大学'],
                    ['南开大学','天津大学','天津师范大学'],
                    ['山东大学','中国海洋大学']]
schoolNames[0][1] = '垃圾学校'
print(schoolNames)
# Out:
# [['北京大学', '垃圾学校'], ['南开大学', '天津大学', '天津师范大学'], ['山东大学', '中国海洋大学']]

# %% [markdown]
# ## 元组

# %%
x = (1,2,3,'you','ha')
print(x)
# Out:
# (1, 2, 3, 'you', 'ha')

# %% [markdown]
# python中不允许修改元组的数据，包括不能删除其中的元素。

# %% [markdown]
# 元组内置函数count, index,用法与列表相似。

# %% [markdown]
# ## 字典

# %%
info = {'name':'班长', 'id':100, 'sex':'f', 'address':'地球亚洲中国北京'}
print(info['address'])
# Out:
# 地球亚洲中国北京

# %% [markdown]
# ### <1> 查看元素

# %% [markdown]
# 不确定字典中是否存在某个键而又想获取其值时，可以使用get方法。

# %%
info = {'name':'班长', 'id':100, 'sex':'f', 'address':'地球亚洲中国北京'}
sex = info.get('sex')
print(sex)
# Out:
# f

# %% [markdown]
# ### <2> 修改元素

# %%
info = {'name':'班长', 'id':100, 'sex':'f', 'address':'地球亚洲中国北京'}

newId = input('请输入新的学号：')

info['id'] = int(newId)

print('修改之后的id为%d:'%info['id'])
# Out:
# 修改之后的id为1314:

# %% [markdown]
# ### <3> 添加元素

# %%
info = {'name':'班长', 'sex':'f', 'address':'地球亚洲中国北京'}

info['title'] = '教授'
print(info)
# Out:
# {'name': '班长', 'sex': 'f', 'address': '地球亚洲中国北京', 'title': '教授'}

# %% [markdown]
# ### <4> 删除元素

# %%
info = {'name':'monitor', 'sex':'f', 'address':'China'}
print(info)
# Out:
# {'name': 'monitor', 'sex': 'f', 'address': 'China'}

# %%
del info['name']
print(info)
# Out:
# {'sex': 'f', 'address': 'China'}

# %%
info.clear()
print(info)
# Out:
# {}

# %%
del info
print(info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# k:\WPS_Cloud_Zone\python_jupyter_notebook\Untitled.ipynb Cell 207 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/k%3A/WPS_Cloud_Zone/python_jupyter_notebook/Untitled.ipynb#Y444sZmlsZQ%3D%3D?line=0'>1</a> del info
# ----> <a href='vscode-notebook-cell:/k%3A/WPS_Cloud_Zone/python_jupyter_notebook/Untitled.ipynb#Y444sZmlsZQ%3D%3D?line=1'>2</a> print(info)
#
# NameError: name 'info' is not defined

# %% [markdown]
# ### <5> len()

# %%
dict = {'name':'zhangsan', 'sex':'female'}
print(len(dict))
# Out:
# 2

# %% [markdown]
# ### <6> keys

# %%
dict = {'name':'zhangsan', 'sex':'female'}
print(dict.keys())
# Out:
# dict_keys(['name', 'sex'])

# %% [markdown]
# ### <7> values

# %%
dict = {'name':'zhangsan', 'sex':'female'}
print(dict.values())
# Out:
# dict_values(['zhangsan', 'female'])

# %% [markdown]
# ### <8> items

# %%
dict = {'name':'zhangsan', 'sex':'female'}
print(dict.items())
# Out:
# dict_items([('name', 'zhangsan'), ('sex', 'female')])

# %% [markdown]
# ## 总结

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
chars = ['a', 'b', 'c', 'd']
for i, chr in enumerate(chars):
    print(i, chr)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 函数

# %% [markdown]
# ## 函数文档说明

# %%
def test(a, b):
    print("%d"%(a + b))

# %%
test(11,22)
# Out:
# 33

# %%
print(help(test))
# Out:
# Help on function test in module __main__:
#
# test(a, b)
#
# None

# %% [markdown]
# ## 函数参数

# %% [markdown]
# ### 定义带有参数的函数

# %%
def add2num(a, b):
    c = a + b
    print(c)

# %% [markdown]
# ### 调用带有参数的函数

# %%
add2num(11, 22)
# Out:
# 33

# %% [markdown]
# ### 调用函数时参数的顺序

# %%
def test(a, b):
    print(a, b)

# %%
test(1,2)
# Out:
# 1 2

# %%
test(2,1)
# Out:
# 2 1

# %%
test(b=2,a=1)
# Out:
# 1 2

# %% [markdown]
# ### 函数返回值

# %%
def add2num(a, b):
    c = a + b
    return c

# %%
x = add2num(1, 2)
print(x)
# Out:
# 3

# %% [markdown]
# ### 函数类型

# %% [markdown]
# <1>无参数，无返回值的函数
# <2>无参数，有返回值的函数
# <3>有参数，无返回值的函数
# <4>有参数，有返回值的函数

# %% [markdown]
# ### 函数的嵌套

# %%
def func1():
    print('This is func1()')

# %%
def func2():
    print('This is func2()')
    func1()

# %%
func2()
# Out:
# This is func2()
# This is func1()

# %% [markdown]
# ### 局部变量和全局变量

# %%
# 全局变量
x = 100
def func1():
    print(x)
def func2():
    print(x)

func1()
func2()
# Out:
# 100
# 100

# %%
# 局部变量
x = 100
def func1():
    x = 300
    print(x)
def func2():
    print(x)
    
func1()
func2()
# Out:
# 300
# 100

# %%
# 局部变量->全局变量
x = 100
def func1():
    global x
    x = 300
    print(x)
def func2():
    print(x)
    
func1()
func2()
# Out:
# 300
# 300

# %% [markdown]
# ### 多个返回值(newB)

# %%
def func(a, b):
    x = a / b
    y = a * b
    return x, y

print(func(13, 2))
# Out:
# (6.5, 26)

# %% [markdown]
# ### 参数

# %% [markdown]
# #### 缺省参数

# %%
# 带有默认值的参数一定要位于参数列表的最后面

def func(a, b = 1, c = 2):
    return a + b + c

# %%
print(func(11, -1, 90))
# Out:
# 100

# %% [markdown]
# #### 不定长参数

# %% [markdown]
# 加了星号（*）的变量args会存放所有未命名的变量参数，args为元组
#
# 加了双星号(**)的变量kwargs会存放命名参数，即形如key=value的参数， kwargs为字典。

# %%
def fun_cs(a, b, *args, **kwargs):
    print ("a =", a)
    print ("b =", b)
    print ("args =", args)
    print ("kwargs: ")
    for key, value in kwargs.items():
        print(key, ' = ', value)

# %%
fun_cs(1, 2, 3, 4, 5, x = -1, y = -2, z = -3)
# Out:
# a = 1
# b = 2
# args = (3, 4, 5)
# kwargs:
# x  =  -1
# y  =  -2
# z  =  -3

# %%
c = (1,2,3)
d = {'name':'rose', 'money':'1000$', 'sex':'unkown'}
fun_cs(a, b, *c, **d)
# Out:
# a = [-100, -1, 10, 4]
# b = [3, 4]
# args = (1, 2, 3)
# kwargs:
# name  =  rose
# money  =  1000$
# sex  =  unkown

# %% [markdown]
# #### 参数引用

# %%
def selfAdd(x):
    x = x + x
    print(x)

list_test = [1, 2]
selfAdd(list_test)
# Out:
# [1, 2, 1, 2]

# %% [markdown]
# ### 引用测试

# %%
a = 1
b = a
print(a)
print(b)
# Out:
# 1
# 1

# %%
a = [1, 2, 3]
b = [1, 2, 3]
a.append(4)
print(a)

print(b)

print(id(a))
print(id(b))
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]
# 2498269371008
# 2498261990464

# %% [markdown]
# ### 递归函数

# %%
def cal_num(num):
    i = 1
    result = 0
    while i <= num:
        result = result + i
        i = i + 1
    return result

ret = cal_num(100)
print(ret)
# Out:
# 5050

# %% [markdown]
# ### lambda函数/匿名函数

# %%
sum = lambda x, y : x + y
print(sum(10, 20))
# Out:
# 30

# %% [markdown]
# # 文件

# %% [markdown]
# ## <1> 打开文件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <2> 关闭文件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <3> 文件的读和写

# %% [markdown]
# ### 写数据

# %%
# 如果文件不存在那么创建，如果存在那么就先清空，然后写入数据
f = open('test.txt', 'w')
f.write('hello world, i am here!')
f.close()

# %% [markdown]
# ### 读数据(read)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 使用read(num)可以从文件中读取数据，num表示要从文件中读取的数据的长度（单位是字节）。
#
# 如果没有传入num，那么就表示读取文件中的所有数据。
#
# 注意：
#
#     如果open是打开一个文件，那么可以不用写打开的模式，只写 open('test.txt')
#
#     如果使用读多次，那么后面读取的数据是从上次读完后的位置开始的

# %% [markdown]
# ### 读数据(readlines)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# readlines可以按照行的方式把整个文件中的内容进行一次性读取，并且返回的是一个列表，其中每一行的数据为一个元素

# %% [markdown]
# ### 读数据(readline）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 制作文件备份

# %%
# 提示输入文件
oldFileName = input("请输入要拷贝的文件名字:")

# 以读的方式打开文件
oldFile = open(oldFileName,'rb')

# 提取文件的后缀
fileFlagNum = oldFileName.rfind('.')
if fileFlagNum > 0:
    fileFlag = oldFileName[fileFlagNum:]

# 组织新的文件名字
newFileName = oldFileName[:fileFlagNum] + '[复件]' + fileFlag

# 创建新文件
newFile = open(newFileName, 'wb')

# 把旧文件中的数据，一行一行的进行复制到新文件中
for lineContent in oldFile.readlines():
    newFile.write(lineContent)

# 关闭文件
oldFile.close()
newFile.close()

# %% [markdown]
# ### 文件的定位读写

# %% [markdown]
# #### <1> 获取当前读写的位置 tell()

# %%
# 打开一个已经存在的文件
f = open("test.txt", "r")
str = f.read(3)
print "读取的数据是 : ", str

# 查找当前位置
position = f.tell()
print "当前文件位置 : ", position

str = f.read(3)
print "读取的数据是 : ", str

# 查找当前位置
position = f.tell()
print "当前文件位置 : ", position

f.close()

# %% [markdown]
# #### <2>定位到某个位置 seek()

# %% [markdown]
# seek(offset, from)有2个参数
#
#     offset:偏移量
#     from:方向
#         0:表示文件开头
#         1:表示当前位置
#         2:表示文件末尾

# %%
# 从文件开头，偏移5个字节

# 打开一个已经存在的文件
f = open("test.txt", "r")
str = f.read(30)
print "读取的数据是 : ", str

# 查找当前位置
position = f.tell()
print "当前文件位置 : ", position

# 重新设置位置
f.seek(5,0)

# 查找当前位置
position = f.tell()
print "当前文件位置 : ", position

f.close()

# %%
# 离文件末尾，3字节处

# 打开一个已经存在的文件
f = open("test.txt", "r")

# 查找当前位置
position = f.tell()
print "当前文件位置 : ", position

# 重新设置位置
f.seek(-3,2)

# 读取到的数据为：文件最后3个字节数据
str = f.read()
print "读取的数据是 : ", str

f.close()

# %% [markdown]
# ## 文件相关操作

# %% [markdown]
# **1.文件重命名**
#
# os模块中的rename()可以完成对文件的重命名操作
#
# rename(需要修改的文件名, 新的文件名)
#
#     import os
#     os.rename("毕业论文.txt", "毕业论文-最终版.txt")
#
# **2.删除文件**
#
# os模块中的remove()可以完成对文件的删除操作
#
# remove(待删除的文件名)
#
#     import os
#     os.remove("毕业论文.txt")
# **3.创建文件夹**
#
#     import os
#     os.mkdir("张三")
#
# **4.获取当前目录**
#
#     import os
#     os.getcwd()
#
# **5.改变默认目录**
#
#     import os
#     os.chdir("../")
#
# **6.获取目录列表**
#
#     import os
#     os.listdir("./")
#
# **7.删除文件夹**
#
#     import os
#     os.rmdir("张三")

# %% [markdown]
# ## 批量修改文件名称

# %%
 #coding=utf-8

# 批量在文件名前加前缀

import os

funFlag = 1 # 1表示添加标志  2表示删除标志

folderName = './renameDir/'

# 获取指定路径的所有文件名字
dirList = os.listdir(folderName)

# 遍历输出所有文件名字
for name in dirList:
    print name

    if funFlag == 1:
        newName = '[东哥出品]-' + name
    elif funFlag == 2:
        num = len('[东哥出品]-')
        newName = name[num:]
    print newName

    os.rename(folderName+name, folderName+newName)

# %% [markdown]
# # 面向对象

# %% [markdown]
# ## 类的构成

# %% [markdown]
# 类的名称:类名
# 类的属性:一组数据
# 类的方法:允许对数据进行操作的方法 (行为)

# %% [markdown]
# ## 定义类

# %%
# 定义类
class Car:
    # 方法
    def getCarInfo(self):
        print('车轮子个数:%d, 颜色%s'%(self.wheelNum, self.color))

    def move(self):
        print("车正在移动...")

# %% [markdown]
# ## 创建对象

# %%
# 定义类
class Car:
    # 移动
    def move(self):
        print('车在奔跑...')

    # 鸣笛
    def toot(self):
        print("车在鸣笛...嘟嘟..")


# 创建一个对象，并用变量BMW来保存它的引用
BMW = Car()
BMW.color = '黑色'
BMW.wheelNum = 4 #轮子数量
BMW.move()
BMW.toot()
print(BMW.color)
print(BMW.wheelNum)
# Out:
# 车在奔跑...
# 车在鸣笛...嘟嘟..
# 黑色
# 4

# %% [markdown]
# ## self

# %%
# 定义一个类
class Animal:

    # 方法
    def __init__(self, name):
        self.name = name

    def printName(self):
        print('名字为:%s'%self.name)

# 定义一个函数
def myPrint(animal):
    animal.printName()


dog1 = Animal('西西')
myPrint(dog1)

dog2 = Animal('北北')
myPrint(dog2)
# Out:
# 名字为:西西
# 名字为:北北

# %% [markdown]
# 可以把self当做C++中类里面的this指针一样理解，就是对象自身的意思。

# %% [markdown]
# ## 魔法函数init

# %% [markdown]
# 相当于是构造函数

# %%
# 定义汽车类
class Car:

    def __init__(self, newWheelNum, newColor):
        self.wheelNum = newWheelNum
        self.color = newColor

    def move(self):
        print('车在跑，目标:夏威夷')

# 创建对象
BMW = Car(4, 'green')

print('车的颜色为:%s'%BMW.color)
print('车轮子数量为:%d'%BMW.wheelNum)
# Out:
# 车的颜色为:green
# 车轮子数量为:4

# %% [markdown]
# ## 魔法函数str

# %%
class Car:

    def __init__(self, newWheelNum, newColor):
        self.wheelNum = newWheelNum
        self.color = newColor

    def __str__(self):
        msg = "嘿。。。我的颜色是" + self.color + "我有" + self.wheelNum + "个轮胎..."
        return msg

    def move(self):
        print('车在跑，目标:夏威夷')


BMW = Car('4', "白色")
print(BMW)
# Out:
# 嘿。。。我的颜色是白色我有4个轮胎...

# %% [markdown]
# ## 面向对象-属性

# %%
class People(object):

    def __init__(self, name):
        self.__name = name

    def getName(self):
        return self.__name

    def setName(self, newName):
        if len(newName) >= 5:
            self.__name = newName
        else:
            print("error:名字长度需要大于或者等于5")

xiaoming = People("dongGe")

xiaoming.setName("wanger")
print(xiaoming.getName())

xiaoming.setName("lisi")
print(xiaoming.getName())
# Out:
# wanger
# error:名字长度需要大于或者等于5
# wanger

# %% [markdown]
# Python中没有像C++中public和private这些关键字来区别公有属性和私有属性。
#
# 它是以属性命名方式来区分，如果在属性名前面加了2个下划线'__'，则表明该属性是私有属性，否则为公有属性（方法也是一样，方法名前面加了2个下划线的话表示该方法是私有的，否则为公有的）。

# %% [markdown]
# ## 魔法函数del

# %%
import time
class Animal(object):
    # 构造函数
    def __init__(self, name):
        print('__init__方法被调用')
        self.__name = name
        
    # 析构函数
    def __del__(self):
        print('__del__方法被调用')
        
dog = Animal('哈皮狗')
del dog
# Out:
# __init__方法被调用
# __del__方法被调用

# %% [markdown]
# ## 单继承

# %%
# 定义一个父类，如下:
class Cat(object):

    def __init__(self, name, color="白色"):
        self.name = name
        self.color = color

    def run(self):
        print("%s--在跑"%self.name)


# 定义一个子类，继承Cat类如下:
class Bosi(Cat):

    def setNewName(self, newName):
        self.name = newName

    def eat(self):
        print("%s--在吃"%self.name)


bs = Bosi("印度猫")
print('bs的名字为:%s'%bs.name)
print('bs的颜色为:%s'%bs.color)
bs.eat()
bs.setNewName('波斯猫')
bs.run()
# Out:
# bs的名字为:印度猫
# bs的颜色为:白色
# 印度猫--在吃
# 波斯猫--在跑

# %% [markdown]
# **总结**
#
# 子类在继承的时候，在定义类时，小括号()中为父类的名字
#
# 父类的属性、方法，会被继承给子类

# %%
class Animal(object):

    def __init__(self, name='动物', color='白色'):
        self.__name = name
        self.color = color

    def __test(self):
        print(self.__name)
        print(self.color)

    def test(self):
        print(self.__name)
        print(self.color)



class Dog(Animal):
    def dogTest1(self):
        #print(self.__name) #不能访问到父类的私有属性
        print(self.color)


    def dogTest2(self):
        #self.__test() #不能访问父类中的私有方法
        self.test()


A = Animal()
#print(A.__name) #程序出现异常，不能访问私有属性
print(A.color)
#A.__test() #程序出现异常，不能访问私有方法
A.test()

print("------分割线-----")

D = Dog(name = "小花狗", color = "黄色")
D.dogTest1()
D.dogTest2()
# Out:
# 白色
# 动物
# 白色
# ------分割线-----
# 黄色
# 小花狗
# 黄色

# %% [markdown]
# 私有的属性，不能通过对象直接访问，但是可以通过方法访问
#
# 私有的方法，不能通过对象直接访问
#
# 私有的属性、方法，不会被子类继承，也不能被访问

# %% [markdown]
# ## 多继承

# %%
# 定义一个父类
class A:
    def printA(self):
        print('----A----')

# 定义一个父类
class B:
    def printB(self):
        print('----B----')

# 定义一个子类，继承自A、B
class C(A,B):
    def printC(self):
        print('----C----')

obj_C = C()
obj_C.printA()
obj_C.printB()
# Out:
# ----A----
# ----B----

# %%
#coding=utf-8
class base(object):
    def test(self):
        print('----base test----')
class A(base):
    def test(self):
        print('----A test----')

# 定义一个父类
class B(base):
    def test(self):
        print('----B test----')

# 定义一个子类，继承自A、B
class C(A,B):
    pass


obj_C = C()
obj_C.test()

print(C.__mro__) #可以查看C类的对象搜索方法时的先后顺序
# Out:
# ----A test----
# (<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.base'>, <class 'object'>)

# %% [markdown]
# ## 重写父类

# %%
#coding=utf-8
class Cat(object):
    def sayHello(self):
        print("halou-----1")


class Bosi(Cat):

    def sayHello(self):
        print("halou-----2")

bosi = Bosi()

bosi.sayHello()
# Out:
# halou-----2

# %% [markdown]
# ## 调用父类

# %%
#coding=utf-8
class Cat(object):
    def __init__(self,name):
        self.name = name
        self.color = 'yellow'


class Bosi(Cat):

    def __init__(self,name):
        # 调用父类的__init__方法1(python2)
        #Cat.__init__(self,name)
        # 调用父类的__init__方法2
        #super(Bosi,self).__init__(name)
        # 调用父类的__init__方法3
        super().__init__(name)

    def getName(self):
        return self.name

bosi = Bosi('xiaohua')

print(bosi.name)
print(bosi.color)
# Out:
# xiaohua
# yellow

# %% [markdown]
# ## 多态

# %%
class F1(object):
    def show(self):
        print('F1.show')

class S1(F1):
    def show(self):
        print('S1.show')

class S2(F1):
    def show(self):
        print('S2.show')

# %%
def Func(obj):
    print(obj.show())

s1_obj = S1()
Func(s1_obj)

s2_obj = S2()
Func(s2_obj)
# Out:
# S1.show
# None
# S2.show
# None

# %% [markdown]
# ## 类的属性

# %%
class People(object):
    name = 'Tom'   #公有的类属性
    __age = 12     #私有的类属性

p = People()

print(p.name)           #正确
print(People.name)      #正确
# print(p.__age)            #错误，不能在类外通过实例对象访问私有的类属性
# print(People.__age)       #错误，不能在类外通过类对象访问私有的类属性
# Out:
# Tom
# Tom

# %%
class People(object):
    address = '山东' #类属性
    def __init__(self):
        self.name = 'xiaowang' #实例属性
        self.age = 20 #实例属性

p = People()
p.age =12 #实例属性
print(p.address) #正确
print(p.name)    #正确
print(p.age)     #正确

print(People.address) #正确
# print(People.name)    #错误
# print(People.age)     #错误
# Out:
# 山东
# xiaowang
# 12
# 山东

# %%
class People(object):
    country = 'china' #类属性


print(People.country) # 输出 china
p = People()
print(p.country) # 输出 china
p.country = 'japan' 
print(p.country)      #实例属性会屏蔽掉同名的类属性 # 输出 japan
print(People.country) # 输出 japan
del p.country    #删除实例属性
print(p.country) # 输出 china
# Out:
# china
# china
# japan
# china
# china

# %% [markdown]
# **总结**
# * 如果需要在类外修改类属性，必须通过类对象引用然后去修改。
# * 如果通过实例对象去引用，会产生一个同名的实例属性，这种方式修改的是实例属性，不会影响到类属性，并且之后如果通过实例对象去引用该名称的属性，实例属性会强制屏蔽掉类属性，即引用的是实例属性，除非删除了该实例属性。

# %% [markdown]
# ## 静态方法和类方法

# %% [markdown]
# ### 类方法

# %%
class People(object):
    country = 'china'

    #类方法，用classmethod来进行修饰
    @classmethod
    def getCountry(cls):
        return cls.country

p = People()
print(p.getCountry())    #可以用过实例对象引用
print(People.getCountry())    #可以通过类对象引用
# Out:
# china
# china

# %% [markdown]
# 类方法还有一个用途就是可以对类属性进行修改。

# %%
class People(object):
    country = 'china'

    #类方法，用classmethod来进行修饰
    @classmethod
    def getCountry(cls):
        return cls.country

    @classmethod
    def setCountry(cls,country):
        cls.country = country


p = People()
print(p.getCountry())    #可以用过实例对象引用 # 输出 china
print(People.getCountry())    #可以通过类对象引用 # 输出 china

p.setCountry('japan')   

print(p.getCountry())   # japan
print(People.getCountry()) # japan
# Out:
# china
# china
# japan
# japan

# %% [markdown]
# ### 静态方法

# %%
class People(object):
    country = 'china'

    @staticmethod
    #静态方法
    def getCountry():
        return People.country


print(People.getCountry())
# Out:
# china

# %% [markdown]
# **总结**
# * 类方法的第一个参数是类对象cls，通过cls引用的必定是类对象的属性和方法
# * 实例方法的第一个参数是实例对象self，通过self引用的可能是类属性、也有可能是实例属性（这个需要具体分析），不过在存在相同名称的类属性和实例属性的情况下，实例属性优先级更高。
# * 静态方法中不需要额外定义参数，因此在静态方法中引用类属性的话，必须通过类对象来引用

# %% [markdown]
# ## 异常

# %% [markdown]
# ### 魔法函数new

# %%
class A(object):
    def __init__(self):
        print("这是 init 方法")

    def __new__(cls):
        print("这是 new 方法")
        return object.__new__(cls)

A()
# Out:
# 这是 new 方法
# 这是 init 方法

# %% [markdown]
# **总结**
# * __new__至少要有一个参数cls，代表要实例化的类，此参数在实例化时由Python解释器自动提供
#
# * __new__必须要有返回值，返回实例化出来的实例，这点在自己实现__new__时要特别注意，可以return 父类__new__出来的实例，或者直接是object的__new__出来的实例
#
# * __init__有一个参数self，就是这个__new__返回的实例，__init__在__new__的基础上可以完成一些其它初始化的动作，__init__不需要返回值
#
# * ? 我们可以将类比作制造商，__new__方法就是前期的原材料购买环节，__init__方法就是在有原材料的基础上，加工，初始化商品环节

# %% [markdown]
# ### 单例模式

# %% [markdown]
# 确保某一个类只有一个实例，而且自行实例化并向整个系统提供这个实例，这个类称为单例类，单例模式是一种对象创建型模式。

# %%
# 实例化一个单例
class Singleton(object):
    __instance = None

    def __new__(cls, age, name):
        #如果类属性__instance的值为None，
        #那么就创建一个对象，并且赋值为这个对象的引用，保证下次调用这个方法时
        #能够知道之前已经创建过对象了，这样就保证了只有1个对象
        if not cls.__instance:
            cls.__instance = object.__new__(cls)
        return cls.__instance

a = Singleton(18, "dongGe")
b = Singleton(8, "dongGe")

print(id(a))
print(id(b))

a.age = 19 #给a指向的对象添加一个属性
print(b.age)#获取b指向的对象的age属性
# Out:
# 2498266508592
# 2498266508592
# 19

# %%
# 实例化一个单例
class Singleton(object):
    __instance = None
    __first_init = False

    def __new__(cls, age, name):
        if not cls.__instance:
            cls.__instance = object.__new__(cls)
        return cls.__instance

    def __init__(self, age, name):
        if not self.__first_init:
            self.age = age
            self.name = name
            Singleton.__first_init = True


a = Singleton(18, "dongGe")
b = Singleton(8, "dongGe")

print(id(a))
print(id(b))


print(a.age)
print(b.age)

a.age = 19
print(b.age)
# Out:
# 2498232400576
# 2498232400576
# 18
# 18
# 19

# %% [markdown]
# ### 捕获异常

# %%
try:
    print('-----test--1---')
    open('123.txt','r')
    print('-----test--2---')
except IOError:
    pass
# Out:
# -----test--1---

# %%
try:
    print('-----test--1---')
    open('123.txt','r')
    print('-----test--2---')
except IOError:
    print("What?")
# Out:
# -----test--1---
# What?

# %%
try:
    print(num)
except IOError:
    print('产生错误了')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [168], in <cell line: 1>()
#       1 try:
# ----> 2     print(num)
#       3 except IOError:
#       4     print('产生错误了')
#
# NameError: name 'num' is not defined

# %%
try:
    print(num)
except NameError:
    print('产生错误了')
# Out:
# 产生错误了

# %%
#coding=utf-8
try:
    print('-----test--1---')
    open('123.txt','r') # 如果123.txt文件不存在，那么会产生 IOError 异常
    print('-----test--2---')
    print(num)# 如果num变量没有定义，那么会产生 NameError 异常

except (IOError,NameError): 
    #如果想通过一次except捕获到多个异常可以用一个元组的方式
    print("show me the code")
# Out:
# -----test--1---
# show me the code

# %%
try:
    num = 100
    print(num)
except NameError as errorMsg:
    print('产生错误了:%s'%errorMsg)
else:
    print('没有捕获到异常，真高兴')
# Out:
# 100
# 没有捕获到异常，真高兴

# %%
try:
#     numx = 100
    print(numx)
except NameError as errorMsg:
    print('产生错误了:%s'%errorMsg)
else:
    print('没有捕获到异常，真高兴')
# Out:
# 产生错误了:name 'numx' is not defined

# %% [markdown]
# 如果一个段代码必须要执行，即无论异常是否产生都要执行，那么此时就需要使用finally。 比如文件关闭，释放锁，把数据库连接返还给连接池等。

# %%
try:
    f = open('test.txt')
    try:
        while True:
            content = f.readline()
            if len(content) == 0:
                break
            print(content)
    except:
        #如果在读取文件的过程中，产生了异常，那么就会捕获到
        #比如 按下了 ctrl+c
        pass
    finally:
        f.close()
        print('关闭文件')
except:
    print("没有这个文件")
# Out:
# Hello,this is a test file for jupyter notebook.
# 关闭文件

# %% [markdown]
# 如果一个异常是在一个函数中产生的，例如函数A---->函数B---->函数C,而异常是在函数C中产生的，那么如果函数C中没有对这个异常进行处理，那么这个异常会传递到函数B中，如果函数B有异常处理那么就会按照函数B的处理方式进行执行；如果函数B也没有异常处理，那么这个异常会继续传递，以此类推。。。如果所有的函数都没有处理，那么此时就会进行异常的默认处理，即通常见到的那样。

# %% [markdown]
# ### 抛出自定义的异常

# %%
class ShortInputException(Exception):
    '''自定义的异常类'''
    def __init__(self, length, atleast):
        self.length = length
        self.atleast = atleast

def main():
    try:
        s = input('请输入 --> ')
        if len(s) < 3:
            # raise引发一个你定义的异常
            raise ShortInputException(len(s), 3)
    except ShortInputException as result:#x这个变量被绑定到了错误的实例
        print('ShortInputException: 输入的长度是 %d,长度至少应是 %d'% (result.length, result.atleast))
    else:
        print('没有异常发生.')

main()
# Out:
# 请输入 --> 12
# ShortInputException: 输入的长度是 2,长度至少应是 3

# %% [markdown]
# ### 异常处理中抛出异常

# %%
class Test(object):
    def __init__(self, switch):
        self.switch = switch #开关
    def calc(self, a, b):
        try:
            return a / b
        except Exception as result:
            if self.switch:
                print("捕获开启，已经捕获到了异常，信息如下:")
                print(result)
            else:
                #重新抛出这个异常，此时就不会被这个异常处理给捕获到，从而触发默认的异常处理
                raise


a = Test(True)
a.calc(11,0)

print("----------------------华丽的分割线----------------")

a.switch = False
a.calc(11,0)
# Out:
# 捕获开启，已经捕获到了异常，信息如下:
# division by zero
# ----------------------华丽的分割线----------------
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [184], in <cell line: 22>()
#      19 print("----------------------华丽的分割线----------------")
#      21 a.switch = False
# ---> 22 a.calc(11,0)
#
# Input In [184], in Test.calc(self, a, b)
#       4 def calc(self, a, b):
#       5     try:
# ----> 6         return a / b
#       7     except Exception as result:
#       8         if self.switch:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## 模块

# %%
import math
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %% [markdown]
# <1> as
#
# <2>import
#
# <3>from…import
#
# <4>from … import *

# %%
import sys
print(sys.path)
# Out:
# ['K:\\WPS_Cloud_Zone\\python_jupyter_notebook', 's:\\anaconda3\\python39.zip', 's:\\anaconda3\\DLLs', 's:\\anaconda3\\lib', 's:\\anaconda3', '', 's:\\anaconda3\\lib\\site-packages', 's:\\anaconda3\\lib\\site-packages\\win32', 's:\\anaconda3\\lib\\site-packages\\win32\\lib', 's:\\anaconda3\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# ### 自制模块

# %% [markdown]
# 假设有文件 demo.py,内容如下：

# %%
def add(x, y):
    return x + y

# %% [markdown]
# 开始测试：

# %%
import demo

result = demo.add(1, 2)
print(result)
# Out:
# 3

# %%
result = demo.add(111, 23)
print(result)
# Out:
# 134

# %% [markdown]
# ### 魔法函数main

# %%
def add(x, y, z):
    return x + y + z
print("in file,__name__ is %s" % __name__)
# Out:
# in file,__name__ is __main__

# %% [markdown]
# 可以根据__name__变量的结果能够判断出，是直接执行的python脚本还是被引入执行的，从而能够有选择性的执行测试代码。

# %% [markdown]
# ### 魔法函数all

# %% [markdown]
# 如果一个文件中有__all__变量，那么也就意味着这个变量中的元素，不会被from xxx import *时导入。
